# %% [markdown]
# # 1. Import Dependencies

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\priya\appdata\roaming\python\python311\site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\priya\appdata\roaming\python\python311\site-packages (from opencv-python) (1.26.4)

# %%
# Import opencv
import cv2 

# Import uuid
import uuid

# Import Operating System
import os

# Import time
import time

# %% [markdown]
# # 2. Define Images to Collect

# %%
labels = ['thumbsup', 'thumbsdown', 'thankyou', 'livelong']
number_imgs = 5

# %% [markdown]
# # 3. Setup Folders

# %%
IMAGES_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'collectedimages')

# %%
IMAGES_PATH
# Out:
# 'Tensorflow\\workspace\\images\\collectedimages'

# %%
os.name
# Out:
# 'nt'

# %%
if not os.path.exists(IMAGES_PATH):
    if os.name == 'posix':
        # !mkdir -p {IMAGES_PATH}
    if os.name == 'nt':
         # !mkdir {IMAGES_PATH}
for label in labels:
    path = os.path.join(IMAGES_PATH, label)
    if not os.path.exists(path):
        # !mkdir {path}

# %% [markdown]
# # 4. Capture Images

# %%
for label in labels:
    cap = cv2.VideoCapture(0)
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    for imgnum in range(number_imgs): 
        print('Collecting image {}'.format(imgnum))
        ret, frame = cap.read()
        imgname = os.path.join(IMAGES_PATH,label,label+'.'+'{}.jpg'.format(str(uuid.uuid1())))
        cv2.imwrite(imgname, frame)
        cv2.imshow('frame', frame)
        time.sleep(2)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()
# Out:
# Collecting images for thumbsup
# Collecting image 0
# Collecting image 1
# Collecting image 2
# Collecting image 3
# Collecting image 4
# Collecting images for thumbsdown
# Collecting image 0
# Collecting image 1
# Collecting image 2
# Collecting image 3
# Collecting image 4
# Collecting images for thankyou
# Collecting image 0
# Collecting image 1
# Collecting image 2
# Collecting image 3
# Collecting image 4
# Collecting images for livelong
# Collecting image 0
# Collecting image 1
# Collecting image 2
# Collecting image 3
# Collecting image 4

# %% [markdown]
# # 5. Image Labelling

# %%
# !pip install --upgrade pyqt5 lxml
# Out:
# Requirement already satisfied: pyqt5 in c:\users\priya\anaconda3\lib\site-packages (5.15.10)
# Collecting pyqt5
#   Using cached PyQt5-5.15.11-cp38-abi3-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: lxml in c:\users\priya\appdata\roaming\python\python311\site-packages (5.3.1)
# Collecting lxml
#   Using cached lxml-6.0.2-cp311-cp311-win_amd64.whl.metadata (3.7 kB)
# Collecting PyQt5-sip<13,>=12.15 (from pyqt5)
#   Using cached pyqt5_sip-12.17.1-cp311-cp311-win_amd64.whl.metadata (515 bytes)
# Collecting PyQt5-Qt5<5.16.0,>=5.15.2 (from pyqt5)
#   Using cached PyQt5_Qt5-5.15.2-py3-none-win_amd64.whl.metadata (552 bytes)
# Using cached PyQt5-5.15.11-cp38-abi3-win_amd64.whl (6.9 MB)
# Using cached PyQt5_Qt5-5.15.2-py3-none-win_amd64.whl (50.1 MB)
# Using cached pyqt5_sip-12.17.1-cp311-cp311-win_amd64.whl (58 kB)
# Using cached lxml-6.0.2-cp311-cp311-win_amd64.whl (4.0 MB)
# Installing collected packages: PyQt5-Qt5, PyQt5-sip, lxml, pyqt5
#
#    ---------------------------------------- 0/4 [PyQt5-Qt5]
#    ---------------------------------------- 0/4 [PyQt5-Qt5]
#    ---------------------------------------- 0/4 [PyQt5-Qt5]
#    ---------------------------------------- 0/4 [PyQt5-Qt5]
#    ---------------------------------------- 0/4 [PyQt5-Qt5]
#    ---------------------------------------- 0/4 [PyQt5-Qt5]
#    ---------------------------------------- 0/4 [PyQt5-Qt5]
#    ---------------------------------------- 0/4 [PyQt5-Qt5]
#    ---------------------------------------- 0/4 [PyQt5-Qt5]
#    ---------------------------------------- 0/4 [PyQt5-Qt5]
#    ---------------------------------------- 0/4 [PyQt5-Qt5]
#    ---------------------------------------- 0/4 [PyQt5-Qt5]
#    ---------------------------------------- 0/4 [PyQt5-Qt5]
#    ---------------------------------------- 0/4 [PyQt5-Qt5]
#    ---------------------------------------- 0/4 [PyQt5-Qt5]
#    ---------------------------------------- 0/4 [PyQt5-Qt5]
#    ---------------------------------------- 0/4 [PyQt5-Qt5]
#    ---------------------------------------- 0/4 [PyQt5-Qt5]
#   Attempting uninstall: PyQt5-sip
#    ---------------------------------------- 0/4 [PyQt5-Qt5]
#     Found existing installation: PyQt5-sip 12.13.0
#    ---------------------------------------- 0/4 [PyQt5-Qt5]
#    ---------- ----------------------------- 1/4 [PyQt5-sip]
#     Uninstalling PyQt5-sip-12.13.0:
#    ---------- ----------------------------- 1/4 [PyQt5-sip]
#       Successfully uninstalled PyQt5-sip-12.13.0
#    ---------- ----------------------------- 1/4 [PyQt5-sip]
#   Attempting uninstall: lxml
#    ---------- ----------------------------- 1/4 [PyQt5-sip]
#     Found existing installation: lxml 5.3.1
#    ---------- ----------------------------- 1/4 [PyQt5-sip]
#    -------------------- ------------------- 2/4 [lxml]
#     Uninstalling lxml-5.3.1:
#    -------------------- ------------------- 2/4 [lxml]
#       Successfully uninstalled lxml-5.3.1
#    -------------------- ------------------- 2/4 [lxml]
#    -------------------- ------------------- 2/4 [lxml]
#    -------------------- ------------------- 2/4 [lxml]
#    -------------------- ------------------- 2/4 [lxml]
#    -------------------- ------------------- 2/4 [lxml]
#    -------------------- ------------------- 2/4 [lxml]
#    -------------------- ------------------- 2/4 [lxml]
#    -------------------- ------------------- 2/4 [lxml]
#    -------------------- ------------------- 2/4 [lxml]
#    -------------------- ------------------- 2/4 [lxml]
#    -------------------- ------------------- 2/4 [lxml]
#    -------------------- ------------------- 2/4 [lxml]
#    -------------------- ------------------- 2/4 [lxml]
#    -------------------- ------------------- 2/4 [lxml]
#    -------------------- ------------------- 2/4 [lxml]
#    -------------------- ------------------- 2/4 [lxml]
#    -------------------- ------------------- 2/4 [lxml]
#    -------------------- ------------------- 2/4 [lxml]
#    -------------------- ------------------- 2/4 [lxml]
#    -------------------- ------------------- 2/4 [lxml]
#    -------------------- ------------------- 2/4 [lxml]
#   Attempting uninstall: pyqt5
#    -------------------- ------------------- 2/4 [lxml]
#     Found existing installation: PyQt5 5.15.10
#    -------------------- ------------------- 2/4 [lxml]
#    ------------------------------ --------- 3/4 [pyqt5]
#    ------------------------------ --------- 3/4 [pyqt5]
#     Uninstalling PyQt5-5.15.10:
#    ------------------------------ --------- 3/4 [pyqt5]
#    ------------------------------ --------- 3/4 [pyqt5]
#       Successfully uninstalled PyQt5-5.15.10
#    ------------------------------ --------- 3/4 [pyqt5]
#    ------------------------------ --------- 3/4 [pyqt5]
#    ------------------------------ --------- 3/4 [pyqt5]
#    ------------------------------ --------- 3/4 [pyqt5]
#    ------------------------------ --------- 3/4 [pyqt5]
#    ------------------------------ --------- 3/4 [pyqt5]
#    ------------------------------ --------- 3/4 [pyqt5]
#    ------------------------------ --------- 3/4 [pyqt5]
#    ------------------------------ --------- 3/4 [pyqt5]
#    ------------------------------ --------- 3/4 [pyqt5]
#    ---------------------------------------- 4/4 [pyqt5]
#
# Successfully installed PyQt5-Qt5-5.15.2 PyQt5-sip-12.17.1 lxml-4.9.3 pyqt5-5.15.11
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Priya\AppData\Roaming\Python\Python311\site-packages\~xml'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.4.3 requires jedi<0.19.0,>=0.17.2, but you have jedi 0.19.1 which is incompatible.

# %%
# !pip list
# Out:
# Package                           Version
# --------------------------------- --------------
# absl-py                           2.1.0
# aiobotocore                       2.7.0
# aiohappyeyeballs                  2.6.1
# aiohttp                           3.11.14
# aioitertools                      0.7.1
# aiosignal                         1.3.2
# alabaster                         0.7.12
# altair                            5.5.0
# anaconda-anon-usage               0.4.3
# anaconda-catalogs                 0.2.0
# anaconda-client                   1.12.3
# anaconda-cloud-auth               0.1.4
# anaconda-navigator                2.5.2
# anaconda-project                  0.11.1
# annotated-types                   0.7.0
# anyascii                          0.3.2
# anyio                             4.9.0
# appdirs                           1.4.4
# archspec                          0.2.1
# argon2-cffi                       23.1.0
# argon2-cffi-bindings              21.2.0
# arrow                             1.3.0
# arxiv                             2.2.0
# astroid                           2.14.2
# astropy                           5.3.4
# asttokens                         2.4.1
# astunparse                        1.6.3
# async-lru                         2.0.4
# asyncer                           0.0.8
# atomicwrites                      1.4.0
# attrs                             25.1.0
# autogen                           0.8.3
# Automat                           20.2.0
# autopep8                          1.6.0
# babel                             2.17.0
# backports.functools-lru-cache     1.6.4
# backports.tempfile                1.0
# backports.weakref                 1.0.post1
# bcrypt                            3.2.0
# beautifulsoup4                    4.13.3
# binaryornot                       0.4.4
# black                             23.11.0
# bleach                            6.2.0
# blinker                           1.8.2
# bokeh                             3.3.4
# boltons                           23.0.0
# botocore                          1.31.64
# Bottleneck                        1.3.7
# Brotli                            1.0.9
# cachetools                        5.5.2
# certifi                           2025.4.26
# cffi                              1.17.1
# chardet                           4.0.0
# charset-normalizer                3.4.1
# click                             8.1.8
# cloudpickle                       2.2.1
# clyent                            1.2.2
# colorama                          0.4.6
# colorcet                          3.0.1
# comm                              0.2.2
# conda                             24.1.2
# conda-build                       24.1.2
# conda-content-trust               0.2.0
# conda_index                       0.4.0
# conda-libmamba-solver             24.1.0
# conda-pack                        0.6.0
# conda-package-handling            2.2.0
# conda_package_streaming           0.9.0
# conda-repo-cli                    1.0.75
# conda-token                       0.4.0
# conda-verify                      3.4.2
# constantly                        23.10.4
# contourpy                         1.3.1
# contractions                      0.1.73
# cookiecutter                      2.5.0
# cryptography                      42.0.2
# cssselect                         1.2.0
# cycler                            0.12.1
# cytoolz                           0.12.2
# dask                              2023.11.0
# dataclasses-json                  0.6.7
# datashader                        0.16.0
# debugpy                           1.8.1
# decorator                         5.1.1
# deep-translator                   1.11.4
# defusedxml                        0.7.1
# diff-match-patch                  20200713
# dill                              0.3.7
# diskcache                         5.6.3
# distlib                           0.3.9
# distributed                       2023.11.0
# distro                            1.9.0
# docker                            7.1.0
# docstring_parser                  0.16
# docstring-to-markdown             0.11
# docutils                          0.18.1
# duckduckgo_search                 7.5.3
# entrypoints                       0.4
# et-xmlfile                        1.1.0
# executing                         2.0.1
# faiss-cpu                         1.10.0
# fastapi                           0.115.11
# fastjsonschema                    2.21.1
# feedparser                        6.0.12
# filelock                          3.18.0
# flake8                            6.0.0
# Flask                             3.0.3
# flatbuffers                       25.1.24
# fonttools                         4.56.0
# fqdn                              1.5.1
# frozendict                        2.4.6
# frozenlist                        1.5.0
# fsspec                            2025.3.0
# future                            0.18.3
# gast                              0.4.0
# gensim                            4.3.0
# gitdb                             4.0.12
# GitPython                         3.1.44
# gmpy2                             2.1.2
# google-ai-generativelanguage      0.6.15
# google-api-core                   2.24.2
# google-api-python-client          2.169.0
# google-auth                       2.39.0
# google-auth-httplib2              0.2.0
# google-auth-oauthlib              1.0.0
# google-cloud-aiplatform           1.90.0
# google-cloud-bigquery             3.31.0
# google-cloud-core                 2.4.3
# google-cloud-resource-manager     1.14.2
# google-cloud-storage              2.19.0
# google-crc32c                     1.7.1
# google-generativeai               0.8.5
# google-pasta                      0.2.0
# google-resumable-media            2.7.2
# googleapis-common-protos          1.70.0
# greenlet                          3.1.1
# groq                              0.20.0
# grpc-google-iam-v1                0.14.2
# grpcio                            1.72.0rc1
# grpcio-status                     1.71.0
# gunicorn                          22.0.0
# h11                               0.16.0
# h5py                              3.12.1
# HeapDict                          1.0.1
# holoviews                         1.18.3
# httpcore                          1.0.9
# httplib2                          0.22.0
# httpx                             0.28.1
# httpx-sse                         0.4.0
# huggingface-hub                   0.34.4
# hvplot                            0.9.2
# hyperlink                         21.0.0
# idna                              3.10
# imagecodecs                       2023.1.23
# imageio                           2.33.1
# imagesize                         1.4.1
# imbalanced-learn                  0.11.0
# importlib-metadata                7.0.1
# incremental                       22.10.0
# inflection                        0.5.1
# iniconfig                         1.1.1
# intake                            0.6.8
# intervaltree                      3.1.0
# ipykernel                         6.29.3
# ipython                           8.22.2
# ipython-genutils                  0.2.0
# ipywidgets                        7.6.5
# isoduration                       20.11.0
# isort                             5.9.3
# itemadapter                       0.3.0
# itemloaders                       1.1.0
# itsdangerous                      2.2.0
# jaraco.classes                    3.2.1
# jax                               0.4.30
# jaxlib                            0.4.30
# jedi                              0.19.1
# jellyfish                         1.0.1
# Jinja2                            3.1.4
# jiter                             0.9.0
# jmespath                          1.0.1
# joblib                            1.4.2
# json5                             0.10.0
# jsonpatch                         1.33
# jsonpointer                       3.0.0
# jsonschema                        4.23.0
# jsonschema-specifications         2024.10.1
# jupyter                           1.0.0
# jupyter_client                    8.6.1
# jupyter-console                   6.6.3
# jupyter_core                      5.7.2
# jupyter-events                    0.12.0
# jupyter-lsp                       2.2.5
# jupyter_server                    2.15.0
# jupyter_server_terminals          0.5.3
# jupyterlab                        4.3.5
# jupyterlab_pygments               0.3.0
# jupyterlab_server                 2.27.3
# jupyterlab-widgets                3.0.9
# keras                             2.12.0
# keyring                           23.13.1
# kiwisolver                        1.4.8
# langchain                         0.3.27
# langchain-community               0.3.20
# langchain-core                    0.3.76
# langchain-huggingface             0.3.1
# langchain-openai                  0.3.33
# langchain-text-splitters          0.3.11
# langsmith                         0.3.45
# lazy_loader                       0.3
# lazy-object-proxy                 1.6.0
# lckr_jupyterlab_variableinspector 3.1.0
# libarchive-c                      2.9
# libclang                          18.1.1
# libmambapy                        1.5.6
# linkify-it-py                     2.0.0
# llvmlite                          0.42.0
# lmdb                              1.4.1
# locket                            1.0.0
# lxml                              4.9.3
# lz4                               4.3.2
# Markdown                          3.7
# markdown-it-py                    3.0.0
# MarkupSafe                        2.1.5
# marshmallow                       3.26.1
# matplotlib                        3.10.1
# matplotlib-inline                 0.1.6
# mccabe                            0.7.0
# mdit-py-plugins                   0.3.0
# mdurl                             0.1.2
# mediapipe                         0.10.21
# menuinst                          2.0.2
# mistune                           3.1.2
# mkl-fft                           1.3.8
# mkl-random                        1.2.4
# mkl-service                       2.4.0
# ml-dtypes                         0.4.1
# more-itertools                    10.1.0
# mpmath                            1.3.0
# msgpack                           1.0.3
# multidict                         6.2.0
# multipledispatch                  0.6.0
# multitasking                      0.0.11
# munkres                           1.1.4
# mypy                              1.8.0
# mypy-extensions                   1.0.0
# mysql-connector-python            8.4.0
# namex                             0.0.8
# narwhals                          1.32.0
# navigator-updater                 0.4.0
# nbclient                          0.10.2
# nbconvert                         7.16.6
# nbformat                          5.10.4
# nest-asyncio                      1.6.0
# networkx                          3.4.2
# nltk                              3.9.1
# notebook                          7.3.2
# notebook_shim                     0.2.4
# numba                             0.59.0
# numexpr                           2.8.7
# numpy                             1.26.4
# numpydoc                          1.5.0
# oauthlib                          3.2.2
# openai                            1.109.1
# opencv-contrib-python             4.11.0.86
# opencv-python                     4.11.0.86
# opencv-python-headless            4.11.0.86
# openpyxl                          3.0.10
# opt_einsum                        3.4.0
# optree                            0.14.0
# orjson                            3.10.16
# overrides                         7.7.0
# packaging                         24.2
# pandas                            2.1.4
# pandocfilters                     1.5.1
# panel                             1.3.8
# param                             2.0.2
# paramiko                          2.8.1
# parsel                            1.8.1
# parso                             0.8.3
# partd                             1.4.1
# pathlib                           1.0.1
# pathspec                          0.10.3
# patsy                             0.5.3
# peewee                            3.17.9
# pexpect                           4.8.0
# phidata                           2.7.10
# pickleshare                       0.7.5
# pillow                            11.1.0
# pip                               23.3.1
# pipenv                            2024.4.1
# pkce                              1.0.3
# pkginfo                           1.9.6
# platformdirs                      4.2.0
# plotly                            5.9.0
# pluggy                            1.0.0
# ply                               3.11
# primp                             0.14.0
# prometheus_client                 0.21.1
# prompt-toolkit                    3.0.43
# propcache                         0.3.1
# Protego                           0.1.16
# proto-plus                        1.26.1
# protobuf                          5.29.4
# psutil                            5.9.8
# ptyprocess                        0.7.0
# pure-eval                         0.2.2
# py-cpuinfo                        9.0.0
# pyahocorasick                     2.1.0
# pyarrow                           19.0.1
# pyasn1                            0.6.1
# pyasn1_modules                    0.4.2
# pyautogen                         0.8.3
# pycodestyle                       2.10.0
# pycosat                           0.6.6
# pycparser                         2.22
# pyct                              0.5.0
# pycurl                            7.45.2
# pydantic                          2.11.4
# pydantic_core                     2.33.2
# pydantic-settings                 2.8.1
# pydeck                            0.9.1
# PyDispatcher                      2.0.5
# pydocstyle                        6.3.0
# pyerfa                            2.0.0
# pyflakes                          3.0.1
# Pygments                          2.17.2
# PyJWT                             2.4.0
# pylint                            2.16.2
# pylint-venv                       2.3.0
# pyls-spyder                       0.4.0
# PyNaCl                            1.5.0
# pyodbc                            5.0.1
# pyOpenSSL                         24.0.0
# pyparsing                         3.2.1
# pypdf                             5.4.0
# PyQt5                             5.15.11
# PyQt5-Qt5                         5.15.2
# PyQt5_sip                         12.17.1
# PyQtWebEngine                     5.15.6
# PySocks                           1.7.1
# pytest                            7.4.0
# python-dateutil                   2.9.0.post0
# python-dotenv                     1.1.1
# python-json-logger                3.2.1
# python-lsp-black                  1.2.1
# python-lsp-jsonrpc                1.0.0
# python-lsp-server                 1.7.2
# python-multipart                  0.0.20
# python-slugify                    5.0.2
# python-snappy                     0.6.1
# pytoolconfig                      1.2.6
# pytz                              2024.1
# pyviz_comms                       3.0.0
# pywavelets                        1.5.0
# pywin32                           306
# pywin32-ctypes                    0.2.0
# pywinpty                          2.0.15
# PyYAML                            6.0.2
# pyzmq                             25.1.2
# QDarkStyle                        3.0.2
# qstylizer                         0.2.2
# QtAwesome                         1.2.2
# qtconsole                         5.4.2
# QtPy                              2.4.1
# queuelib                          1.6.2
# referencing                       0.36.2
# regex                             2024.11.6
# requests                          2.32.3
# requests-file                     1.5.1
# requests-oauthlib                 2.0.0
# requests-toolbelt                 1.0.0
# rfc3339-validator                 0.1.4
# rfc3986-validator                 0.1.1
# rich                              13.9.4
# rope                              1.7.0
# rpds-py                           0.23.1
# rsa                               4.9.1
# Rtree                             1.0.1
# ruamel.yaml                       0.17.21
# ruamel-yaml-conda                 0.17.21
# s3fs                              2023.10.0
# safetensors                       0.5.3
# scikit-image                      0.22.0
# scikit-learn                      1.3.2
# scipy                             1.14.0
# Scrapy                            2.8.0
# seaborn                           0.12.2
# semver                            2.13.0
# Send2Trash                        1.8.3
# sentence-transformers             4.0.1
# sentencepiece                     0.2.0
# service-identity                  18.1.0
# setuptools                        78.1.0
# sgmllib3k                         1.0.0
# shapely                           2.1.0
# shellingham                       1.5.4
# sip                               6.7.12
# six                               1.16.0
# smart-open                        5.2.1
# smmap                             5.0.2
# sniffio                           1.3.1
# snowballstemmer                   2.2.0
# sortedcontainers                  2.4.0
# sounddevice                       0.5.1
# soupsieve                         2.6
# Sphinx                            5.0.2
# sphinxcontrib-applehelp           1.0.2
# sphinxcontrib-devhelp             1.0.2
# sphinxcontrib-htmlhelp            2.0.0
# sphinxcontrib-jsmath              1.0.1
# sphinxcontrib-qthelp              1.0.3
# sphinxcontrib-serializinghtml     1.1.5
# spyder                            5.4.3
# spyder-kernels                    2.4.4
# SQLAlchemy                        2.0.40
# stack-data                        0.6.3
# starlette                         0.46.0
# statsmodels                       0.14.0
# streamlit                         1.49.1
# sympy                             1.14.0
# tables                            3.9.2
# tabulate                          0.9.0
# tblib                             1.7.0
# tenacity                          9.0.0
# tensorboard                       2.12.3
# tensorboard-data-server           0.7.2
# tensorflow                        2.12.0
# tensorflow-estimator              2.12.0
# tensorflow-intel                  2.12.0
# tensorflow-io-gcs-filesystem      0.31.0
# termcolor                         2.5.0
# terminado                         0.18.1
# text-unidecode                    1.3
# textblob                          0.19.0
# textdistance                      4.2.1
# textsearch                        0.0.24
# tf_keras                          2.19.0
# threadpoolctl                     3.5.0
# three-merge                       0.1.1
# tifffile                          2023.4.12
# tiktoken                          0.9.0
# tinycss2                          1.4.0
# tldextract                        3.2.0
# tokenizers                        0.21.1
# toml                              0.10.2
# tomli                             2.2.1
# tomlkit                           0.11.1
# toolz                             0.12.0
# torch                             2.8.0
# torchaudio                        2.8.0
# torchvision                       0.23.0
# tornado                           6.4
# tqdm                              4.67.1
# traitlets                         5.14.2
# transformers                      4.50.3
# truststore                        0.8.0
# Twisted                           23.10.0
# twisted-iocpsupport               1.0.2
# typer                             0.15.2
# types-python-dateutil             2.9.0.20241206
# typing_extensions                 4.13.2
# typing-inspect                    0.9.0
# typing-inspection                 0.4.0
# tzdata                            2024.1
# tzlocal                           2.1
# uc-micro-py                       1.0.1
# ujson                             5.4.0
# Unidecode                         1.2.0
# uri-template                      1.3.0
# uritemplate                       4.1.1
# urllib3                           2.3.0
# uvicorn                           0.34.0
# validators                        0.18.2
# virtualenv                        20.29.3
# w3lib                             2.1.2
# watchdog                          6.0.0
# wcwidth                           0.2.13
# webcolors                         24.11.1
# webencodings                      0.5.1
# websocket-client                  1.8.0
# Werkzeug                          3.0.3
# whatthepatch                      1.0.2
# wheel                             0.45.1
# widgetsnbextension                3.5.2
# win-inet-pton                     1.1.0
# wrapt                             1.14.1
# xarray                            2023.6.0
# xlwings                           0.29.1
# xyzservices                       2022.9.0
# yapf                              0.31.0
# yarl                              1.18.3
# yfinance                          0.2.55
# zict                              3.0.0
# zipp                              3.17.0
# zope.interface                    5.4.0
# zstandard                         0.23.0

# %%
LABELIMG_PATH = os.path.join('Tensorflow', 'labelimg')

# %%
if not os.path.exists(LABELIMG_PATH):
    # !mkdir {LABELIMG_PATH}
    # !git clone https://github.com/tzutalin/labelImg {LABELIMG_PATH}

# %%
LABELIMG_PATH
# Out:
# 'Tensorflow\\labelimg'

# %%
if os.name == 'posix':
    # !cd {LABELIMG_PATH} && make qt5py3
if os.name =='nt':
    # !cd {LABELIMG_PATH} && pyrcc5 -o libs/resources.py resources.qrc

# %%
# !cd {LABELIMG_PATH} && python labelImg.py
# Out:
# Cancel creation.
# Image:C:\Users\Priya\Desktop\Tensorflow Object Detection\TFODCourse\Tensorflow\workspace\images\collectedimages\thankyou\8e73b6be-21e1-45c6-bb97-b1e57f82841f.jpg -> Annotation:C:/Users/Priya/Desktop/Tensorflow Object Detection/TFODCourse/Tensorflow/workspace/images/collectedimages/thankyou\8e73b6be-21e1-45c6-bb97-b1e57f82841f.xml
# Image:C:\Users\Priya\Desktop\Tensorflow Object Detection\TFODCourse\Tensorflow\workspace\images\collectedimages\thankyou\40c23ddb-5884-40c7-8857-1d8c89cadbfc.jpg -> Annotation:C:/Users/Priya/Desktop/Tensorflow Object Detection/TFODCourse/Tensorflow/workspace/images/collectedimages/thankyou\40c23ddb-5884-40c7-8857-1d8c89cadbfc.xml
# Image:C:\Users\Priya\Desktop\Tensorflow Object Detection\TFODCourse\Tensorflow\workspace\images\collectedimages\thankyou\53527b95-c739-4ea1-a69f-087a6feb9ea2.jpg -> Annotation:C:/Users/Priya/Desktop/Tensorflow Object Detection/TFODCourse/Tensorflow/workspace/images/collectedimages/thankyou\53527b95-c739-4ea1-a69f-087a6feb9ea2.xml
# Image:C:\Users\Priya\Desktop\Tensorflow Object Detection\TFODCourse\Tensorflow\workspace\images\collectedimages\thankyou\bb304601-525f-42e9-b6bd-863c589b7246.jpg -> Annotation:C:/Users/Priya/Desktop/Tensorflow Object Detection/TFODCourse/Tensorflow/workspace/images/collectedimages/thankyou\bb304601-525f-42e9-b6bd-863c589b7246.xml
# Cancel creation.
# Cancel creation.
# Image:C:\Users\Priya\Desktop\Tensorflow Object Detection\TFODCourse\Tensorflow\workspace\images\collectedimages\thankyou\c434a8e3-0dbd-49ed-b30a-57308b2fea26.jpg -> Annotation:C:/Users/Priya/Desktop/Tensorflow Object Detection/TFODCourse/Tensorflow/workspace/images/collectedimages/thankyou\c434a8e3-0dbd-49ed-b30a-57308b2fea26.xml
# Image:C:\Users\Priya\Desktop\Tensorflow Object Detection\TFODCourse\Tensorflow\workspace\images\collectedimages\thumbsdown\0cc21eee-8b27-4008-a7fa-a4d6efdf7096.jpg -> Annotation:C:/Users/Priya/Desktop/Tensorflow Object Detection/TFODCourse/Tensorflow/workspace/images/collectedimages/thumbsdown\0cc21eee-8b27-4008-a7fa-a4d6efdf7096.xml
# Image:C:\Users\Priya\Desktop\Tensorflow Object Detection\TFODCourse\Tensorflow\workspace\images\collectedimages\thumbsdown\8a7df4c4-5181-4c8a-98ca-ce070337c3f9.jpg -> Annotation:C:/Users/Priya/Desktop/Tensorflow Object Detection/TFODCourse/Tensorflow/workspace/images/collectedimages/thumbsdown\8a7df4c4-5181-4c8a-98ca-ce070337c3f9.xml
# Image:C:\Users\Priya\Desktop\Tensorflow Object Detection\TFODCourse\Tensorflow\workspace\images\collectedimages\thumbsdown\09ed38f6-9e49-4d74-9223-9855dfa8aad1.jpg -> Annotation:C:/Users/Priya/Desktop/Tensorflow Object Detection/TFODCourse/Tensorflow/workspace/images/collectedimages/thumbsdown\09ed38f6-9e49-4d74-9223-9855dfa8aad1.xml
# Image:C:\Users\Priya\Desktop\Tensorflow Object Detection\TFODCourse\Tensorflow\workspace\images\collectedimages\thumbsdown\31bd2619-0568-435d-986c-b9aef3c30e90.jpg -> Annotation:C:/Users/Priya/Desktop/Tensorflow Object Detection/TFODCourse/Tensorflow/workspace/images/collectedimages/thumbsdown\31bd2619-0568-435d-986c-b9aef3c30e90.xml
# Image:C:\Users\Priya\Desktop\Tensorflow Object Detection\TFODCourse\Tensorflow\workspace\images\collectedimages\thumbsdown\724b1857-9183-40ee-ad11-3ce0ff0853d3.jpg -> Annotation:C:/Users/Priya/Desktop/Tensorflow Object Detection/TFODCourse/Tensorflow/workspace/images/collectedimages/thumbsdown\724b1857-9183-40ee-ad11-3ce0ff0853d3.xml
# Image:C:\Users\Priya\Desktop\Tensorflow Object Detection\TFODCourse\Tensorflow\workspace\images\collectedimages\thumbsup\77d05c25-a0e8-48f1-b03b-0af4f8eea02b.jpg -> Annotation:C:/Users/Priya/Desktop/Tensorflow Object Detection/TFODCourse/Tensorflow/workspace/images/collectedimages/thumbsup\77d05c25-a0e8-48f1-b03b-0af4f8eea02b.xml
# Image:C:\Users\Priya\Desktop\Tensorflow Object Detection\TFODCourse\Tensorflow\workspace\images\collectedimages\thumbsup\3310c802-3d9b-4308-8baa-a3103d84a1b2.jpg -> Annotation:C:/Users/Priya/Desktop/Tensorflow Object Detection/TFODCourse/Tensorflow/workspace/images/collectedimages/thumbsup\3310c802-3d9b-4308-8baa-a3103d84a1b2.xml
# Image:C:\Users\Priya\Desktop\Tensorflow Object Detection\TFODCourse\Tensorflow\workspace\images\collectedimages\thumbsup\8091a1a0-228f-4a97-ac72-8649da017413.jpg -> Annotation:C:/Users/Priya/Desktop/Tensorflow Object Detection/TFODCourse/Tensorflow/workspace/images/collectedimages/thumbsup\8091a1a0-228f-4a97-ac72-8649da017413.xml
# Image:C:\Users\Priya\Desktop\Tensorflow Object Detection\TFODCourse\Tensorflow\workspace\images\collectedimages\thumbsup\22401fc7-531f-4356-8636-b501d17f1b5e (1).jpg -> Annotation:C:/Users/Priya/Desktop/Tensorflow Object Detection/TFODCourse/Tensorflow/workspace/images/collectedimages/thumbsup\22401fc7-531f-4356-8636-b501d17f1b5e (1).xml
# Image:C:\Users\Priya\Desktop\Tensorflow Object Detection\TFODCourse\Tensorflow\workspace\images\collectedimages\thumbsup\f9c2aeaf-5c26-4974-98fb-705316d50785 (1).jpg -> Annotation:C:/Users/Priya/Desktop/Tensorflow Object Detection/TFODCourse/Tensorflow/workspace/images/collectedimages/thumbsup\f9c2aeaf-5c26-4974-98fb-705316d50785 (1).xml

# %% [markdown]
# # 6. Move them into a Training and Testing Partition

# %% [markdown]
# # OPTIONAL - 7. Compress them for Colab Training

# %%
TRAIN_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'train')
TEST_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'test')
ARCHIVE_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'archive.tar.gz')

# %%
# !tar -czf {ARCHIVE_PATH} {TRAIN_PATH} {TEST_PATH}
